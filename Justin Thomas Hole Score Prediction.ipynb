# %% [markdown]
# ### TODO
#
# - Download OWGR historical information
# - Apply OWGR as strength of field feature
# - Gather golfer summary statistics as features
# - Update score prediction for the hole after each shot?
# - Gather SG stats for golfer and merge with course features

# %%
import numpy as np
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import time
import math
import pickle

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.utils import shuffle

from sklearn import linear_model
from sklearn import ensemble

from sklearn import metrics

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
TRAIN_FILE = './data/phil-mickelson-strokes-train.csv'
TEST_FILE = './data/phil-mickelson-strokes-test.csv'

# %%
df = pd.read_csv(TRAIN_FILE, index_col=None)
df.head()
# Out:
#    Year  Tourn.#  Player #     Player Name  Course #              Course Name  \
# 0  2010       40      1810  Phil Mickelson         4  Torrey Pines GC (South)
# 1  2010       40      1810  Phil Mickelson         4  Torrey Pines GC (South)
# 2  2010       40      1810  Phil Mickelson         4  Torrey Pines GC (South)
# 3  2010       40      1810  Phil Mickelson         4  Torrey Pines GC (South)
# 4  2010       40      1810  Phil Mickelson         4  Torrey Pines GC (South)
#
#    Round  Hole  Par Value  Yardage  Shot Shot Type(S/P/D)  \
# 0      1     1          4      450     1                S
# 1      1     1          4      450     2                S
# 2      1     1          4      450     3                S
# 3      1     1          4      450     4                S
# 4      1     2          4      389     1                S
#
#   From Location(Scorer)      From Location(Enhanced) To Location(Scorer)  \
# 0               Tee Box                      Tee Box             Fairway
# 1               Fairway                Right Fairway   Green Side Bunker
# 2     Green Side Bunker  Left Rear Green Side Bunker               Green
# 3                 Green                        Green                   0
# 4               Tee Box                      Tee Box      Fairway Bunker
#
#          To Location(Enhanced)  Distance to Pin Around the Green Flag  \
# 0                Right Fairway            16164                     N
# 1  Left Rear Green Side Bunker             5048                     Y
# 2                        Green              352                     N
# 3                            0               24                     N
# 4               Fairway Bunker            13680                     N
#
#   1st Putt Flag  Time   Lie Elevation  Slope  Distance from Center  \
# 0             0   901  Good      With  Level                    92
# 1             0   907  Good      With  Level                   205
# 2             0   910  Good      With  Level                     1
# 3             Y   913  Good      With  Level                     0
# 4             0   916  Good      With  Level                   585
#
#    Distance from Edge Left/Right Recovery Shot              Tee Grass  \
# 0                 274          R            No  Bermudagrass/Ryegrass
# 1                 146          0            No  Bermudagrass/Ryegrass
# 2                 167          L            No  Bermudagrass/Ryegrass
# 3                   0          0            No  Bermudagrass/Ryegrass
# 4                 185          L            No  Bermudagrass/Ryegrass
#
#   Fwy Firmness  Fwy Height   Fwy. Grass Grn Firmness  Grn Height Green Grass  \
# 0       Medium         0.5  Kikuyugrass         Soft        0.11   Poa annua
# 1       Medium         0.5  Kikuyugrass         Soft        0.11   Poa annua
# 2       Medium         0.5  Kikuyugrass         Soft        0.11   Poa annua
# 3       Medium         0.5  Kikuyugrass         Soft        0.11   Poa annua
# 4       Medium         0.5  Kikuyugrass         Soft        0.11   Poa annua
#
#    Rough Height         Rough Grass  Stimp AM Wind Spd AM Wind Dir  \
# 0           3.5  Perennial Ryegrass   12.0           c           C
# 1           3.5  Perennial Ryegrass   12.0           c           C
# 2           3.5  Perennial Ryegrass   12.0           c           C
# 3           3.5  Perennial Ryegrass   12.0           c           C
# 4           3.5  Perennial Ryegrass   12.0           c           C
#
#   PM Wind Spd PM Wind Dir  Fwy Width 250  Fwy Width 275  Fwy Width 300  \
# 0           5          IW           25.0           24.0           23.0
# 1           5          IW           25.0           24.0           23.0
# 2           5          IW           25.0           24.0           23.0
# 3           5          IW           25.0           24.0           23.0
# 4           5          RL           27.0           23.0           24.0
#
#    Fwy Width 325  Fwy Width 350  Actual 250 Distance  Actual 275 Distance  \
# 0           23.0           22.0                 27.0                 30.0
# 1           23.0           22.0                 27.0                 30.0
# 2           23.0           22.0                 27.0                 30.0
# 3           23.0           22.0                 27.0                 30.0
# 4           21.0           14.0                 25.0                 27.0
#
#    Actual 300 Distance  Actual 325 Distance  Actual 350 Distance  Par  \
# 0                 32.0                 35.0                 37.0  4.0
# 1                 32.0                 35.0                 37.0  4.0
# 2                 32.0                 35.0                 37.0  4.0
# 3                 32.0                 35.0                 37.0  4.0
# 4                 30.0                 32.0                 35.0  4.0
#
#    Scorecard Ydg  Actual Ydg
# 0          450.0       449.0
# 1          450.0       449.0
# 2          450.0       449.0
# 3          450.0       449.0
# 4          389.0       380.0

# %%
def load_and_process_data(file):
    df = pd.read_csv(file, index_col=None)
    
    df.drop(
        columns=['Player Name', 'Course Name', 'AM Wind Spd', 'AM Wind Dir', 'PM Wind Spd', 'PM Wind Dir'],
        axis=1,
        inplace=True
    )
    
    df.drop(
        columns=['Tee Grass', 'Fwy. Grass', 'Green Grass', 'Rough Grass', 'From Location(Enhanced)', 'To Location(Enhanced)'],
        axis=1,
        inplace=True
    )
    
    # year, tourn #, player #?, course #, round, hole, shot, time, one par, scorecard yrd, actual yrd, shot type, recovery shot
    df.drop(
        columns=['Tourn.#', 'Player #', 'Course #', 'Round', 'Hole', 'Shot', 'Time', 'Par', 'Scorecard Ydg', 'Actual Ydg', 'Shot Type(S/P/D)', 'Recovery Shot'],
        axis=1,
        inplace=True
    )
    
    #df = pd.get_dummies(df, 
    #                    prefix=['Shot_Type', 'Around_the_Green', '1st_Putt', 'Left_Right', 'Recovery_Shot'], 
    #                    columns=['Shot Type(S/P/D)', 'Around the Green Flag', '1st Putt Flag', 'Left/Right', 'Recovery Shot'])
    df = pd.get_dummies(df, 
                        prefix=['Around_the_Green', '1st_Putt', 'Left_Right'], 
                        columns=['Around the Green Flag', '1st Putt Flag', 'Left/Right'])
    
    encodings = {
        'Lie': {
            'Good': 1, 
            '0': -1, 
            'Unknown': -1, 
            'Buried': 2
        },
        'Elevation': {
            'With': 1, 
            'Below Ball': 2, 
            '0': -1, 
            'Unmapped': -1, 
            'Above Ball': 2, 
            'Unknown': -1
        },
        'Slope': {
            'Level': 1, 
            'Downhill': 2,
            '0': -1, 
            'Unknown': -1,
            'Uphill': 2
        },
        'Fwy Firmness': {
            'Medium': 1, 
            'Firm': 2, 
            'Soft': 0, 
            'Unknown': -1
        },
        'Grn Firmness': {
            'Soft': 0, 
            'Medium': 1, 
            'Firm': 2,
            'Unknown': -1
        },
        'From Location(Scorer)': {
            'Tee Box': 0, 
            'Fairway': 1, 
            'Fringe': 2, 
            'Green': 3, 
            'Intermediate Rough': 4, 
            'Primary Rough': 5, 
            'Green Side Bunker': 6, 
            'Fairway Bunker': 7, 
            'Native Area': 8, 
            '0': -1, 
            'Unknown': -1, 
            'Other': 9, 
            'Water': 10
        },
        'To Location(Scorer)': {
            'Tee Box': 0, 
            'Fairway': 1, 
            'Fringe': 2,
            'Green': 3, 
            'Intermediate Rough': 4, 
            'Primary Rough': 5, 
            'Green Side Bunker': 6, 
            'Fairway Bunker': 7,
            'Waste Bunker': 7, 
            'Tree Outline': 8, 
            'Rock Outline': 8, 
            'Dirt Outline': 8,
            'Cart Path': 9, 
            'Path': 9,
            'Native Area': 10, 
            'Water': 11,
            '0': -1, 
            'Unknown': -1
        }
    }
    df.replace(encodings, inplace=True)
    
    # rearrage columns
    cols = df.columns.tolist()
    df = df[cols[4:6] + cols[:4] + cols[6:]]
    
    # drop nan
    df.dropna(inplace=True)
    
    return df
