# %% [markdown]
# ### TODO
#
# - Download OWGR historical information
# - Apply OWGR as strength of field feature
# - Gather golfer summary statistics as features
# - Update score prediction for the hole after each shot?
# - Gather SG stats for golfer and merge with course features

# %%
import numpy as np
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import time
import math
import pickle

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.utils import shuffle

from sklearn import linear_model
from sklearn import ensemble

from sklearn import metrics

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
TRAIN_FILE = './data/justin-thomas-holes-train.csv'
VALIDATION_FILE = './data/justin-thomas-holes-validation.csv'
TEST_FILE = './data/justin-thomas-holes-test.csv'

# %%
df = pd.read_csv(TRAIN_FILE, index_col=None)
df.head()
# Out:
#    Year  PlayerNumber  HoleNumber  CourseNumber                       Course  \
# 0  2016         33448           1           776  Sea Island Resort (Seaside)
# 1  2016         33448           1           776  Sea Island Resort (Seaside)
# 2  2016         33448           1           776  Sea Island Resort (Seaside)
# 3  2016         33448           1            36         Firestone CC (South)
# 4  2016         33448           1            36         Firestone CC (South)
#
#    AvgPuttsGained  AvgSGT2G  AvgSGTotal  AvgOTTSG  AvgAppSG  AvgARGSG  \
# 0       -0.185013  0.505507    0.320453  0.029067  0.493667 -0.017453
# 1       -0.185013  0.505507    0.320453  0.029067  0.493667 -0.017453
# 2       -0.185013  0.505507    0.320453  0.029067  0.493667 -0.017453
# 3       -0.185013  0.505507    0.320453  0.029067  0.493667 -0.017453
# 4       -0.185013  0.505507    0.320453  0.029067  0.493667 -0.017453
#
#    DrivingDistanceAvg  DrivingAccuracyAvg  AvgEagles  AvgBirdies  AvgPars  \
# 0          293.604762            0.534286          0           3       11
# 1          293.604762            0.534286          0           3       11
# 2          293.604762            0.534286          0           3       11
# 3          293.604762            0.534286          0           3       11
# 4          293.604762            0.534286          0           3       11
#
#    AvgBogies  AvgDoubles  AvgOthers  App5075ftAvg  App75100ftAvg  \
# 0          2           0          0        14.213      19.695299
# 1          2           0          0        14.213      19.695299
# 2          2           0          0        14.213      19.695299
# 3          2           0          0        14.213      19.695299
# 4          2           0          0        14.213      19.695299
#
#    App100125ftAvg  App50125ftAvg  App125150ftAvg  App150175ftAvg  \
# 0       18.040868      18.260482       22.183331       24.792382
# 1       18.040868      18.260482       22.183331       24.792382
# 2       18.040868      18.260482       22.183331       24.792382
# 3       18.040868      18.260482       22.183331       24.792382
# 4       18.040868      18.260482       22.183331       24.792382
#
#    App175200ftAvg  App200ftAvg    AvgGIR  AvgProximityToHole  \
# 0       31.326881    44.423923  0.657037           35.287862
# 1       31.326881    44.423923  0.657037           35.287862
# 2       31.326881    44.423923  0.657037           35.287862
# 3       31.326881    44.423923  0.657037           35.287862
# 4       31.326881    44.423923  0.657037           35.287862
#
#    AvgScramblingProximityToHole  AvgSandProximityToHole  PuttingInside5Ft  \
# 0                      8.578867                9.810045          1.029693
# 1                      8.578867                9.810045          1.029693
# 2                      8.578867                9.810045          1.029693
# 3                      8.578867                9.810045          1.029693
# 4                      8.578867                9.810045          1.029693
#
#    PuttingInside10Ft  Putting5Ft10Ft  Putting4Ft8Ft  Putting10Ft15Ft  \
# 0           0.880661        1.745856        0.66879         0.247826
# 1           0.880661        1.745856        0.66879         0.247826
# 2           0.880661        1.745856        0.66879         0.247826
# 3           0.880661        1.745856        0.66879         0.247826
# 4           0.880661        1.745856        0.66879         0.247826
#
#    Putting15Ft20Ft  Putting20Ft25Ft  PuttingOver10Ft  PuttingOver25Ft  \
# 0         0.184211         0.102564         0.136476         0.042345
# 1         0.184211         0.102564         0.136476         0.042345
# 2         0.184211         0.102564         0.136476         0.042345
# 3         0.184211         0.102564         0.136476         0.042345
# 4         0.184211         0.102564         0.136476         0.042345
#
#    Yardage  Par  FairwayHeight  GreenHeight  RoughHeight  Stimp  FwyWidth250  \
# 0      411    4            0.5          0.9         2.25   11.0           25
# 1      409    4            0.5          0.9         2.25   11.0           25
# 2      420    4            0.5          0.9         2.25   11.0           25
# 3      395    4            0.3          0.1         3.00   12.5           26
# 4      394    4            0.3          0.1         3.00   12.5           26
#
#    FwyWidth275  FwyWidth300  FwyWidth325  FwyWidth350  Score
# 0           27           30           32           35      4
# 1           27           30           32           35      4
# 2           27           30           32           35      5
# 3           28           31           33           36      4
# 4           28           31           33           36      4

# %%
def load_and_process_data(file):
    df = pd.read_csv(file, index_col=None)
    
    df.drop(
        columns=['Year', 'PlayerNumber', 'HoleNumber', 'CourseNumber', 'Course'],
        axis=1,
        inplace=True
    )
    
    df.drop(
        columns=['AvgEagles', 'AvgBirdies', 'AvgPars', 'AvgBogies', 'AvgDoubles', 'AvgOthers'],
        axis=1,
        inplace=True
    )
    
    # drop nan
    df.dropna(inplace=True)
    
    return df

# %%
def split_data(df):
    #return X, y
    return df[df.columns[:-1]], df['Score']

# %%
def normalize_data(X):
    cols = X.columns
    return pd.DataFrame(MinMaxScaler().fit_transform(X), columns=cols)

# %%
df_train = load_and_process_data(TRAIN_FILE)
df_validation = load_and_process_data(VALIDATION_FILE)
df_test = load_and_process_data(TEST_FILE)

# %%
print('Training Shape', df_train.shape)
print('Validation Shape', df_validation.shape)
print('Test Shape', df_test.shape)
# Out:
# Training Shape (1544, 41)
# Validation Shape (1436, 41)
# Test Shape (1455, 41)

# %%
X_train, y_train = split_data(df_train)
X_validation, y_validation = split_data(df_validation)
X_test, y_test = split_data(df_test)

print('Training X Shape', X_train.shape)
print('Training y Shape', y_train.shape)
print('Validation X Shape', X_validation.shape)
print('Validation y Shape', y_validation.shape)
print('Test X Shape', X_test.shape)
print('Test y Shape', y_test.shape)
# Out:
# Training X Shape (1544, 40)
# Training y Shape (1544,)
# Validation X Shape (1436, 40)
# Validation y Shape (1436,)
# Test X Shape (1455, 40)
# Test y Shape (1455,)

# %%
X_train = normalize_data(X_train)
X_validation = normalize_data(X_validation)
X_test = normalize_data(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor()
rf_reg.fit(X_train, y_train)
rf_reg.score(X_validation, y_validation)
# Out:
# 0.2061120239689861

# %%
feature_importances = pd.DataFrame(rf_reg.feature_importances_,
                                   index = X_train.columns,
                                   columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
#                               importance
# Yardage                         0.356629
# Par                             0.342533
# RoughHeight                     0.062235
# Stimp                           0.046489
# FairwayHeight                   0.045289
# GreenHeight                     0.033230
# FwyWidth325                     0.026703
# FwyWidth350                     0.022791
# FwyWidth275                     0.022741
# FwyWidth250                     0.021734
# FwyWidth300                     0.019626
# AvgSGT2G                        0.000000
# PuttingOver25Ft                 0.000000
# PuttingOver10Ft                 0.000000
# Putting20Ft25Ft                 0.000000
# Putting15Ft20Ft                 0.000000
# Putting10Ft15Ft                 0.000000
# Putting4Ft8Ft                   0.000000
# Putting5Ft10Ft                  0.000000
# PuttingInside10Ft               0.000000
# AvgPuttsGained                  0.000000
# AvgSandProximityToHole          0.000000
# App75100ftAvg                   0.000000
# AvgSGTotal                      0.000000
# AvgOTTSG                        0.000000
# AvgAppSG                        0.000000
# AvgARGSG                        0.000000
# DrivingDistanceAvg              0.000000
# DrivingAccuracyAvg              0.000000
# App5075ftAvg                    0.000000
# App100125ftAvg                  0.000000
# AvgScramblingProximityToHole    0.000000
# App50125ftAvg                   0.000000
# App125150ftAvg                  0.000000
# App150175ftAvg                  0.000000
# App175200ftAvg                  0.000000
# App200ftAvg                     0.000000
# AvgGIR                          0.000000
# AvgProximityToHole              0.000000
# PuttingInside5Ft                0.000000

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
log_reg.score(X_validation, y_validation)
# Out:
# 0.5675487465181058

# %%
df_train.corr()['Score']
# Out:
# AvgPuttsGained                  3.172651e-17
# AvgSGT2G                       -3.069059e-16
# AvgSGTotal                     -4.285325e-16
# AvgOTTSG                        3.069059e-16
# AvgAppSG                       -1.460200e-16
# AvgARGSG                       -1.722737e-16
# DrivingDistanceAvg              1.452779e-16
# DrivingAccuracyAvg              5.345119e-16
# App5075ftAvg                   -2.644032e-16
# App75100ftAvg                  -2.143432e-16
# App100125ftAvg                  6.025355e-16
# App50125ftAvg                  -1.435696e-16
# App125150ftAvg                 -3.547153e-16
# App150175ftAvg                  2.544006e-16
# App175200ftAvg                 -2.544006e-16
# App200ftAvg                    -2.289375e-16
# AvgGIR                         -7.809075e-17
# AvgProximityToHole             -2.433081e-16
# AvgScramblingProximityToHole    1.435696e-16
# AvgSandProximityToHole          1.327085e-16
# PuttingInside5Ft                7.429349e-17
# PuttingInside10Ft              -3.371921e-16
# Putting5Ft10Ft                 -2.099806e-16
# Putting4Ft8Ft                   2.218323e-16
# Putting10Ft15Ft                 3.135439e-16
# Putting15Ft20Ft                -4.098228e-16
# Putting20Ft25Ft                 4.529954e-16
# PuttingOver10Ft                 1.374601e-16
# PuttingOver25Ft                -1.201912e-16
# Yardage                         4.638344e-01
# Par                             5.875519e-01
# FairwayHeight                   4.496556e-02
# GreenHeight                     4.590305e-02
# RoughHeight                     2.637231e-02
# Stimp                           5.611532e-02
# FwyWidth250                     4.838625e-01
# FwyWidth275                     4.824417e-01
# FwyWidth300                     4.676343e-01
# FwyWidth325                     4.624041e-01
# FwyWidth350                     4.452114e-01
# Score                           1.000000e+00
# Name: Score, dtype: float64
